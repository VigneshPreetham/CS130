# %%
from generate import Generator
from matplotlib import pyplot as plt
from PIL import Image

generator = Generator(path="/home/daviddu/CS130/checkpoints/eff_9.pth")

paths = []

with open('paths.txt') as f:
    paths = [line.strip() for line in f]


import random
random.shuffle(paths)
# Out:
# Using cache found in /home/daviddu/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# /home/daviddu/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/daviddu/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(

# %%
examples = 10

for i, path in enumerate(paths):
    if i == examples:
        break
    image = Image.open(path)
    plt.imshow(image)
    plt.show()
    print(f"Predicted: {generator.generate(image)}")
    label = path.split('/')[-2]
    print(f"Actual: {label}")
# Out:
# Predicted: Oysters
# Actual: Oysters
# Predicted: Fried pork in scoop
# Actual: Fried pork in scoop
# Predicted: Pizza
# Actual: Chicken quesadilla
# Predicted: Soba noodle
# Actual: Soba noodle
# Predicted: Pho
# Actual: Pho
# Predicted: Biryani
# Actual: Biryani
# Predicted: Paneer tikka
# Actual: Paneer tikka
# Predicted: Spaghetti carbonara
# Actual: Spaghetti carbonara
# Predicted: Foie gras
# Actual: Foie gras
# Predicted: Beef in oyster sauce
# Actual: Beef in oyster sauce
