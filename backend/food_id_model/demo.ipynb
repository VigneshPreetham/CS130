# %%
from generate import Generator
from matplotlib import pyplot as plt
from PIL import Image

generator = Generator(path="/home/daviddu/CS130/checkpoints/eff_8.pth")

paths = []

with open('paths.txt') as f:
    paths = [line.strip() for line in f]


import random
random.shuffle(paths)
# Out:
# Using cache found in /home/daviddu/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub

# %%
examples = 10

for i, path in enumerate(paths):
    if i == examples:
        break
    image = Image.open(path)
    plt.imshow(image)
    plt.show()
    print(f"Predicted: {generator.generate(image)}")
    label = path.split('/')[-2]
    print(f"Actual: {label}")
# Out:
# Predicted: Cheese plate
# Actual: Cheese plate
# Predicted: Takoyaki
# Actual: Takoyaki
# Predicted: Caesar salad
# Actual: Caesar salad
# Predicted: Hummus
# Actual: Hummus
# Predicted: Cannoli
# Actual: Cannoli
# Predicted: Poutine
# Actual: Poutine
# Predicted: Salade nicoise
# Actual: Salade nicoise
# Predicted: Biryani
# Actual: Biryani
# Predicted: Manti
# Actual: Manti
# Predicted: Saganaki
# Actual: Saganaki
